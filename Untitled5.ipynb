# %% [markdown]
# <a href="https://colab.research.google.com/github/saksham1965/data-analyst/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0b81a8a0-4218-4f1a-bf8e-bb7000b39d9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b81a8a0-4218-4f1a-bf8e-bb7000b39d9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/raw_data_unmodified.csv')
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df = df.replace(['?', 'N/A', 'na', ''], np.nan)
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# director_facebook_likes      2
# actor_3_facebook_likes       0
# actor_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# cast_total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
print(df.isnull().sum())

print(df.isnull().mean() * 100)
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# director_facebook_likes      2
# actor_3_facebook_likes       0
# actor_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# cast_total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64
# movie_title                   0.000000
# num_critic_for_reviews        0.000000
# duration                     21.428571
# director_facebook_likes      14.285714
# actor_3_facebook_likes        0.000000
# actor_1_facebook_likes        0.000000
# gross                         0.000000
# num_voted_users               7.142857
# cast_total_facebook_likes    14.285714
# facenumber_in_poster         35.714286
# num_user_for_reviews          0.000000
# ...

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# director_facebook_likes       object
# actor_3_facebook_likes         int64
# actor_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# cast_total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [movie_title, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_1_facebook_likes, gross, num_voted_users, cast_total_facebook_likes, facenumber_in_poster, num_user_for_reviews, budget, title_year, actor_2_facebook_likes, imdb_score, title_year.1]
# Index: []
